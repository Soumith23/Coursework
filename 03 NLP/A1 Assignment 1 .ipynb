# %%
from pandas import Series, DataFrame
import pandas as pd
# %pylab inline

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
stop_words = set(stopwords.words('english'))

def remstopwords(x):
    text_tokens = word_tokenize(x)
    tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
    return (" ").join(tokens_without_sw)
# this function is to create a new column of text by removing stopwords

# %%
df = pd.read_csv('sample data.csv', header = None)
df = df.rename(columns={0: "user", 1: "Date", 2: "Text"})
df_sample = df[:10].copy()
df_sample
#df['Text_nostopw'] = df['Text'].map(remstopwords)
df_sample['Text_nostopw'] = df_sample['Text'].map(remstopwords)
df_sample
#df
# Out:
#            user   Date                                               Text  \
# 0  brightness04  6-Oct     "  kia hyundai under-achieving  "  kia hyun...
# 1     kdshapiro  6-Oct     "  kia hyundai most bmw's owners paid for t...
# 2     fedlawman  6-Oct     "  kia hyundai it's not a matter of   "  ki...
# 3      rockylee  6-Oct     "  kia hyundai under-achieving  "  kia hyun...
# 4      rockylee  6-Oct   i have 2 friends that own 3 series. i drove b...
# 5        oldcem  6-Oct   neither can the bmw 325is, 2.0t  audi s, etc....
# 6      rockylee  6-Oct   it's not that you don't worship  bmw , the lo...
# 7     dandrews1  6-Oct     "  kia hyundai this thread isn't just about...
# 8      rockylee  6-Oct   i thought we were looking at entry luxury per...
# 9      habitat1  6-Oct   rocky,i'm not going to give you a lesson on e...
#
#                                         Text_nostopw
# 0  `` kia hyundai under-achieving `` kia hyundai ...
# 1  `` kia hyundai bmw 's owners paid badge , car ...
# 2  `` kia hyundai 's matter `` kia hyundai `` kia...
# 3  `` kia hyundai under-achieving `` kia hyundai ...
# 4  2 friends 3 series . drove agree nice car . ot...
# 5       bmw 325is , 2.0t audi , . guess n't belong .
# 6  's n't worship bmw , lord entitled respects th...
# 7  `` kia hyundai thread n't `` kia hyundai entry...
# 8       entry luxury performance ? : confuse : rocky
# 9  rocky , 'm give lesson economics convince buy ...

# %%
df_replace = pd.read_csv('car models and brands (3).csv')

# function to replace models with brands
def replace(x):
    for i in range(len(df_replace)):
        x = x.replace(df_replace.iloc[i]['Model'],df_replace.iloc[i]['Brand'])
        
    return x
        
df_sample['model_replaced'] = df_sample['Text_nostopw'].map(replace)
df_sample
# Out:
#            user   Date                                               Text  \
# 0  brightness04  6-Oct     "  kia hyundai under-achieving  "  kia hyun...
# 1     kdshapiro  6-Oct     "  kia hyundai most bmw's owners paid for t...
# 2     fedlawman  6-Oct     "  kia hyundai it's not a matter of   "  ki...
# 3      rockylee  6-Oct     "  kia hyundai under-achieving  "  kia hyun...
# 4      rockylee  6-Oct   i have 2 friends that own 3 series. i drove b...
# 5        oldcem  6-Oct   neither can the bmw 325is, 2.0t  audi s, etc....
# 6      rockylee  6-Oct   it's not that you don't worship  bmw , the lo...
# 7     dandrews1  6-Oct     "  kia hyundai this thread isn't just about...
# 8      rockylee  6-Oct   i thought we were looking at entry luxury per...
# 9      habitat1  6-Oct   rocky,i'm not going to give you a lesson on e...
#
#                                         Text_nostopw  \
# 0  `` kia hyundai under-achieving `` kia hyundai ...
# 1  `` kia hyundai bmw 's owners paid badge , car ...
# 2  `` kia hyundai 's matter `` kia hyundai `` kia...
# 3  `` kia hyundai under-achieving `` kia hyundai ...
# 4  2 friends 3 series . drove agree nice car . ot...
# 5       bmw 325is , 2.0t audi , . guess n't belong .
# 6  's n't worship bmw , lord entitled respects th...
# 7  `` kia hyundai thread n't `` kia hyundai entry...
# 8       entry luxury performance ? : confuse : rocky
# 9  rocky , 'm give lesson economics convince buy ...
#
#                                       model_replaced
# 0     "  kia hyundai under-achieving  "  kia hyun...
# 1     "  kia hyundai most bmw's owners paid for t...
# 2     "  kia hyundai it's not a matter of   "  ki...
# 3     "  kia hyundai under-achieving  "  kia hyun...
# 4   i have 2 friends that own 3 series. i drove b...
# 5   neither can the bmw bmw, 2.0t  audi s, etc. g...
# 6   it's not that you don't worship  bmw , the lo...
# 7     "  kia hyundai this thread isn't just about...
# 8   i thought we were looking at entry luxury per...
# 9   rocky,i'm not going to give you a lesson on e...
